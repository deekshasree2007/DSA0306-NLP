# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6LGRp8G1uM123YtTqPhhGeI-YHhD1diY6UxTv6vgJEbxw")

prompt = input("Enter a text: ")

response = client.models.generate_content(
    model="gemini-3.5-flash-lite",
    contents=prompt
)

print(response.text)
# Out:
# Enter a text: tell me about nlpp
# Depending on the context, **NLPP** can refer to a few different things, but the most common and significant meaning is **Natural Language Processing Platform**.
#
# Here is a breakdown of what an NLPP is, how it works, and why it matters.
#
# ---
#
# ### 1. Natural Language Processing Platform (Tech & AI)
# In the world of Artificial Intelligence and software development, an NLPP is a suite of tools, libraries, and frameworks that allow developers to build applications capable of understanding, interpreting, and generating human language.
#
# Instead of writing complex algorithms from scratch to understand text or speech, developers use an NLPP to add human-like language capabilities to their software.
#
# #### Key Features of an NLPP:
# *   **Text Classification & Sentiment Analysis:** Determining if a customer review is positive, neutral, or negative.
# ...

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-fr")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-fr")

english_text="Hello,how are you? I am learning NLP."

input_ids = tokenizer(english_text, return_tensors="pt").input_ids
outputs = model.generate(input_ids)
translated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

print("English:",english_text)
print("French:",translated_text)
# Out:
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# English: Hello,how are you? I am learning NLP.
# French: J'apprends le NLP.
